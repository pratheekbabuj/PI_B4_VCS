# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("2016-2017_orig.csv",sep=";")
df
# Out:
#              date               name_1               name_2  age_1  age_2  \
# 0      01.01.2016    Samantha Crawford   Tsvetana Pironkova     20     28
# 1      01.01.2016   Tsvetana Pironkova    Samantha Crawford     28     20
# 2      01.01.2016     Kimberly Birrell           Xinyun Han     17     25
# 3      01.01.2016           Xinyun Han     Kimberly Birrell     25     17
# 4      01.01.2016         Olga Savchuk  Sesil Karatantcheva     28     26
# ...           ...                  ...                  ...    ...    ...
# 85283  31.12.2017            Miyu Kato            Jana Fett     23     21
# 85284  31.12.2017  Ysaline Bonaventure      Arina Rodionova     23     28
# 85285  31.12.2017      Arina Rodionova  Ysaline Bonaventure     28     23
# 85286  31.12.2017     Viktoria Kuzmova          Arantxa Rus     19     27
# 85287  31.12.2017          Arantxa Rus     Viktoria Kuzmova     27     19
#
#        rating_1  rating_2    k1    k2          result  player1_is_win?
# ...

# %%
df.columns
# Out:
# Index(['date', 'name_1', 'name_2', 'age_1', 'age_2', 'rating_1', 'rating_2',
#        'k1', 'k2', 'result', 'player1_is_win?'],
#       dtype='object')

# %%
df.isnull().sum() ### no null values
# Out:
# date               0
# name_1             0
# name_2             0
# age_1              0
# age_2              0
# rating_1           0
# rating_2           0
# k1                 0
# k2                 0
# result             0
# player1_is_win?    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85288 entries, 0 to 85287
# Data columns (total 11 columns):
# date               85288 non-null object
# name_1             85288 non-null object
# name_2             85288 non-null object
# age_1              85288 non-null int64
# age_2              85288 non-null int64
# rating_1           85288 non-null int64
# rating_2           85288 non-null int64
# k1                 85288 non-null float64
# k2                 85288 non-null float64
# result             85288 non-null object
# player1_is_win?    85288 non-null int64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 7.2+ MB

# %%
df.duplicated().sum() # no missing values
# Out:
# 0

# %%
#lets check corelation

# %%
df.dtypes
# Out:
# date                object
# name_1              object
# name_2              object
# age_1                int64
# age_2                int64
# rating_1             int64
# rating_2             int64
# k1                 float64
# k2                 float64
# result              object
# player1_is_win?      int64
# dtype: object

# %%
num_col=df.columns[df.dtypes!="O"]  ## seperating num col
num_col
# Out:
# Index(['age_1', 'age_2', 'rating_1', 'rating_2', 'k1', 'k2',
#        'player1_is_win?'],
#       dtype='object')

# %%
cat_col=df.columns[df.dtypes=="O"]  #cat col

cat_col
# Out:
# Index(['date', 'name_1', 'name_2', 'result'], dtype='object')

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr(),annot=True)  # to check co relation

# %%
sns.pairplot(data=df)  #visualising the corelation
